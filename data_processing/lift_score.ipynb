# %%
import pandas as pd
import numpy as np
from pytrends.request import TrendReq 
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Fetches the missing keywords from google trends
def get_google_trends_to_csv(keyword, df, df_index, df_name = "../data/trend_single_score.csv"):
    comp_time = "2010-01-01 2022-11-19"
    pytrends = TrendReq(hl='en-US', tz=-120, timeout=(10,25), retries = 4, backoff_factor=10)
    pytrends.build_payload([keyword], timeframe=comp_time, geo = "")
    loc_df = pytrends.interest_over_time()

    if(len(loc_df) < 1):
        loc_df = pytrends.interest_over_time()
        if(len(loc_df) < 1):
            with open("../data/lift_score_unpopular_google_searches", "a") as file:
                file.write(str(df_index) + ": " + keyword +"\n")
                return df, False

    loc_df = loc_df.drop(columns="isPartial")
    df = pd.concat([df, loc_df], axis=1)

    df.to_csv(df_name)

    return df, True

#Calculates the lift score = has the word been more or less trendy this month than on average within the last year
def get_lift(keyword, df, year, month, df_index):
    if keyword not in df.columns:
        print("    adding " + keyword + " to data base.")
        df, succeeded = get_google_trends_to_csv(keyword, df, df_index)
        if not succeeded:
            print("    adding failed.")
            return df, 1

    end_index = int(np.where((df.index.year ==  year) & (df.index.month == month))[0])
    start_index = int(np.where((df.index.year ==  year-1) & (df.index.month == month))[0])

    month_score = df.iloc[end_index][keyword]
    mean = df.iloc[start_index:end_index][keyword].mean()

    return df, month_score/(max(mean, 1))

# %%
# Maximal Marginal Relevance
# Returns top_n best keywords
def mmr(doc_embedding, word_embeddings, words, top_n, diversity):

    # Extract similarity within words, and between words and the document
    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)

    # Initialize candidates and already choose best keyword/keyphras
    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    for _ in range(top_n - 1):
        # Extract similarities within candidates and
        # between candidates and selected keywords/phrases
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # Calculate MMR
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # Update keywords & candidates
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
# Preprocesses text and call mmr
# Returns top_n keywords
def get_mmr_keywords(doc, top_n=5):

    n_gram_range = (1,1)
    count = CountVectorizer(ngram_range=n_gram_range, stop_words="english").fit([doc])
    candidates = count.get_feature_names_out()

    model = SentenceTransformer('distilbert-base-nli-mean-tokens')
    doc_embedding = model.encode([doc])
    candidate_embeddings = model.encode(candidates)

    #top_n = 10
    #distances = cosine_similarity(doc_embedding, candidate_embeddings)
    #keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
    #keywords
    if len(candidates) <= top_n:
        return candidates
     
    return mmr(doc_embedding, candidate_embeddings, candidates, top_n=top_n, diversity=0.2)

# %% [markdown]
# # The main loop

# %%
df = pd.read_csv("../data/blogs_with_analytics.csv", sep="\t", parse_dates=["time"], infer_datetime_format=True, index_col=["index"])
keyword_df = pd.read_csv("../data/trend_single_score.csv", parse_dates=["date"], infer_datetime_format=True, index_col=["date"])

for index in range(772, len(df)):
    keywords = get_mmr_keywords(df.iloc[index]["text"])
    print(str(index) + ": " + str(keywords))
    
    lift_sum = 0

    for word in keywords: 
        keyword_df, lift = get_lift(word, keyword_df, int(df.iloc[index]["time"].year), int(df.iloc[index]["time"].month), index)
        lift_sum += lift
        df.at[index, "mmr_lift"] = lift_sum

    df.to_csv("../data/blogs_with_analytics.csv", sep="\t")
# Out:
# 712: ['tuesday', 'finnish', 'female', 'economist', 'teenagers']
# 713: ['google', 'javascript', 'spaghetti', 'superpowers', 'apps']
# 714: ['startups', 'startup', 'mvps', 'innovators', 'innovation']
# 715: ['coaching', 'riskier', 'compete', 'customers', 'help']
#     adding riskier to data base.
#     adding compete to data base.
#     adding help to data base.
# 716: ['festival', 'iphone', 'apps', 'android', 'gig']
#     adding gig to data base.
#     adding failed.
# 717: ['champion', 'august', 'workplace', 'competitive', 'daily']
# 718: ['spring', 'graduated', 'magazine', 'assistant', 'studies']
#     adding magazine to data base.
#     adding failed.
#     adding assistant to data base.
#     adding failed.
#     adding studies to data base.
#     adding failed.
# 719: ['campers', 'magic', 'download', 'caring', 'reward']
#     adding campers to data base.
#     adding caring to data base.
#     adding reward to data base.
#     adding failed.
# 720: ['june', 'colleagues', '2008', 'corporate', '2013']
#     adding 2008 to data base.
# 721: ['june', 'retrospectives', 'sailboat', 'retrospective', 'meeting']
#     adding sailboat to data base.
#     adding retrospective to data base.
# 722: ['developers', 'saturday', 'friends', 'hacking', 'bacon']
# 723: ['blog', 'party', 'javascript', 'multinational', 'months']
# 724: ['june', 'retrospectives', 'monthly', 'instructor', 'blog']
#     adding instructor to data base.
# 725: ['2011', 'workaround', '2013', '2012', 'email']
#     adding 2011 to data base.
#     adding workaround to data base.
#     adding 2012 to data base.
# 726: ['email', 'mislabeled', 'microsoft', 'technologies', 'custom']
#     adding mislabeled to data base.
#     adding failed.
#     adding custom to data base.
# 727: ['organizationalculture', 'competitive', 'innovation', 'orchestrating', 'industries']
#     adding organizationalculture to data base.
#     adding failed.
#     adding orchestrating to data base.
#     adding failed.
#     adding industries to data base.
#     adding failed.
# 728: ['trusted', 'abused', 'willfully', 'high', 'leadership']
#     adding trusted to data base.
#     adding failed.
#     adding abused to data base.
#     adding failed.
#     adding willfully to data base.
#     adding failed.
#     adding high to data base.
# 729: ['mobilemagazines', 'skynews', '20130307', 'twitter', 'magazine']
#     adding mobilemagazines to data base.
#     adding failed.
#     adding skynews to data base.
#     adding 20130307 to data base.
#     adding magazine to data base.
#     adding failed.
# 730: ['tedx', 'consultants', 'joyful', 'rewriting', 'dangerous']
#     adding tedx to data base.
#     adding joyful to data base.
#     adding dangerous to data base.
# 731: ['finland', 'ecstatic', '2020', 'bosses', 'rewarding']
#     adding ecstatic to data base.
#     adding bosses to data base.
# 732: ['designers', 'online', 'training', 'customer', 'business']
# 733: ['photoshop', 'friends', 'chef', 'driver', 'love']
#     adding photoshop to data base.
#     adding chef to data base.
#     adding driver to data base.
#     adding love to data base.
# 734: ['rewarding', 'daily', 'decade', 'partner', 'hard']
#     adding partner to data base.
# 735: ['disappointed', 'customer', 'omniscient', 'software', 'learner']
#     adding disappointed to data base.
#     adding omniscient to data base.
#     adding learner to data base.
# 736: ['service_design_breakfast', 'startup', 'decaying', 'analytics', 'lifecycle']
#     adding service_design_breakfast to data base.
#     adding failed.
#     adding decaying to data base.
# 737: ['email', 'recruiter', 'colleagues', 'staffing', 'interviews']
#     adding recruiter to data base.
#     adding staffing to data base.
# 738: ['partying', 'ceo', 'wine', 'yearly', 'party']
#     adding wine to data base.
# 739: ['podcasts', 'finnish', 'prerecorded', 'radiolupa', 'composers']
#     adding prerecorded to data base.
#     adding radiolupa to data base.
#     adding composers to data base.
# 740: ['hacker', 'mathematical', 'algorithms', 'science', 'academic']
# 741: ['jättijärjestelmissä', 'viimevuotinen', 'julkishallinnollinen', 'tietotekniikkahankintoihin', 'lipunmyyntijärjestelmäänsä']
#     adding jättijärjestelmissä to data base.
#     adding failed.
#     adding viimevuotinen to data base.
#     adding julkishallinnollinen to data base.
#     adding failed.
#     adding tietotekniikkahankintoihin to data base.
#     adding failed.
#     adding lipunmyyntijärjestelmäänsä to data base.
#     adding failed.
# 742: ['happy', 'prize', 'live', 'happiness', 'future']
#     adding prize to data base.
#     adding happiness to data base.
# 743: ['starbucks', 'morning', 'startup', 'london', 'lunch']
#     adding starbucks to data base.
#     adding failed.
#     adding london to data base.
#     adding failed.
# 744: ['google', 'party', 'shortcuts', 'web', 'lifecycle']
#     adding shortcuts to data base.
#     adding failed.
# 745: ['boss', 'futurice_decision_making', 'companies', 'customers', 'rules']
#     adding futurice_decision_making to data base.
#     adding failed.
#     adding rules to data base.
#     adding failed.
# 746: ['workaround', 'researchers', 'mathematical', 'difficult', 'conclusive']
#     adding difficult to data base.
#     adding failed.
#     adding conclusive to data base.
#     adding failed.
# 747: ['browser', 'new', 'localstorage', 'printers', 'pingdom']
#     adding localstorage to data base.
#     adding failed.
#     adding printers to data base.
#     adding failed.
#     adding pingdom to data base.
#     adding failed.
# 748: ['blog', 'months', 'new', 'historical', 'goal']
#     adding historical to data base.
#     adding goal to data base.
# 749: ['helsinkiservicejam2012', 'weekend', '116418736973434902417', 'spring', 'cake']
#     adding helsinkiservicejam2012 to data base.
#     adding failed.
#     adding 116418736973434902417 to data base.
#     adding failed.
# 750: ['party', 'pitkäjännitteinen', 'pizzapäivä', 'workplace', 'finland']
#     adding pitkäjännitteinen to data base.
#     adding failed.
#     adding pizzapäivä to data base.
# 751: ['dinner', 'volunteers', 'lunch', 'android', 'saturday']
# 752: ['rehearsing', 'daily', 'automated', 'developers', 'databases']
#     adding rehearsing to data base.
#     adding automated to data base.
#     adding databases to data base.
# 753: ['django', '_del_field_comments__chg_fieldtimestamp', 'sqlite', 'installed_apps', 'south']
#     adding django to data base.
#     adding _del_field_comments__chg_fieldtimestamp to data base.
#     adding failed.
#     adding sqlite to data base.
#     adding failed.
#     adding installed_apps to data base.
#     adding failed.
#     adding south to data base.
#     adding failed.
# 754: ['businesspeople', 'brandbook', 'architects', 'entrepreneurial', 'unpretentious']
#     adding businesspeople to data base.
#     adding failed.
#     adding brandbook to data base.
#     adding architects to data base.
#     adding unpretentious to data base.
# 755: ['taxi', 'amazon', 'broadband', 'gplv3', 'lobby']
#     adding taxi to data base.
#     adding broadband to data base.
#     adding gplv3 to data base.
# 756: ['wealthy', 'weekend', 'helsinki', 'enthusiasts', 'fast']
#     adding wealthy to data base.
# 757: ['blog', 'html', 'postponing', 'week', 'uploaded']
#     adding postponing to data base.
#     adding uploaded to data base.
# 758: ['daily', 'linux', '750gb', 'backuppc', 'raid5']
#     adding 750gb to data base.
#     adding backuppc to data base.
#     adding raid5 to data base.
#     adding failed.
# 759: ['customers_role_in_project_success', 'party', 'happy', 'server', 'statistical']
#     adding customers_role_in_project_success to data base.
#     adding failed.
#     adding statistical to data base.
# 760: ['friday', 'python', 'keynote', 'magical', 'google']
# 761: ['gps', 'racing', 'sunny', 'browsers', 'nokia']
#     adding gps to data base.
# 762: ['february', 'feminist', 'seminar', 'weekend', 'microwave']
#     adding microwave to data base.
# 763: ['google', 'finnish', 'yearly', 'friends', 'minna']
#     adding minna to data base.
# 764: ['iphone', 'smartphones', 'smartphone', 'android', 'finnish']
# 765: ['teachers', 'skype', 'email', 'homework', 'interviewed']
#     adding interviewed to data base.
# 766: ['competitive', 'geeks', 'expensive', 'wine', 'tedious']
#     adding geeks to data base.
# 767: ['rewrite', 'fedcbaf1821677f02c1c36adb99f5ed3d5a5728d', 'hacking', 'fast', 'rewriting']
#     adding fedcbaf1821677f02c1c36adb99f5ed3d5a5728d to data base.
#     adding failed.
# 768: ['bosses', 'happy', 'compete', 'blog', 'workplaces']
#     adding workplaces to data base.
# 769: ['tester', 'software', 'discouraging', 'developers', 'manufacturing']
#     adding tester to data base.
#     adding discouraging to data base.
#     adding manufacturing to data base.
# 770: ['wealthy', 'bus', 'iphone', 'wifi', 'killer']
#     adding wifi to data base.
# 771: ['ceo', 'wettbewerbsfähiger', 'zentraleuropäischen', 'germany', 'flexibilität']
#     adding wettbewerbsfähiger to data base.
#     adding zentraleuropäischen to data base.
#     adding flexibilität to data base.
# 772: ['server', 'employees', 'employee', 'software', 'servers']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\talvi\Documents\Aalto\Data science project\project git\Futurice-blog-analysis\data_processing\lift_score.ipynb Cell 6 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> lift_sum = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> for word in keywords:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     keyword_df, lift = get_lift(word, keyword_df, int(df.iloc[index]["time"].year), int(df.iloc[index]["time"].month), index)
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>     lift_sum += lift
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a>     df.at[index, "mmr_lift"] = lift_sum
#
# c:\Users\talvi\Documents\Aalto\Data science project\project git\Futurice-blog-analysis\data_processing\lift_score.ipynb Cell 6 in get_lift(keyword, df, year, month, df_index)
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=28'>29</a>         return df, 1
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a> end_index = int(np.where((df.index.year ==  year) & (df.index.month == month))[0])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=31'>32</a> start_index = int(np.where((df.index.year ==  year-1) & (df.index.month == month))[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=33'>34</a> month_score = df.iloc[end_index][keyword]
#      <a href='vscode-notebook-cell:/c%3A/Users/talvi/Documents/Aalto/Data%20science%20project/project%20git/Futurice-blog-analysis/data_processing/lift_score.ipynb#W4sZmlsZQ%3D%3D?line=34'>35</a> mean = df.iloc[start_index:end_index][keyword].mean()
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %% [markdown]
# # Rest of the file is for debuging

# %%
get_mmr_keywords(df.iloc[772]["text"])
# Out:
# ['server', 'employees', 'employee', 'software', 'servers']

# %%
df.iloc[772]
# Out:
# url                                        blog/why-personal-virtual-servers
# title                                          Why personal virtual servers?
# time                                                     2010-12-27 00:00:00
# category                                                             Culture
# description                As Olli mentioned before the holidays, our IT ...
# text                       As Olli mentioned before the holidays, our IT ...
# introduction               ['As', 'Olli', 'mentioned', 'before', 'the', '...
# author                                                         Arttu Tolonen
# author_job_title                                         Communications Lead
# pageviews                                                                  5
# unique_pageviews                                                           3
# avg_time                                                               173.0
# bounce_rate                                                              0.0
# exit%                                                                    0.0
# semantic neg score                                                     0.007
# semantic neu score                                                     0.801
# semantic pos score                                                     0.192
# semantic compound score                                               0.9935
# average_sentence_length                                            19.230769
# dale_chall                                                              8.39
# flesch                                                                 50.36
# average_stopword                                                    8.307692
# mmr_lift                                                                -1.0
# Name: 772, dtype: object

# %%
df["mmr_lift"][0:639].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 639 entries, 0 to 638
# Series name: mmr_lift
# Non-Null Count  Dtype
# --------------  -----
# 639 non-null    float64
# dtypes: float64(1)
# memory usage: 5.1 KB

# %%
comp_time = "2010-01-01 2022-11-19"
pytrends = TrendReq(hl='en-US', tz=-120, timeout=(10,25), retries = 4, backoff_factor=10)
pytrends.build_payload(["mobprogramming"], timeframe=comp_time, geo = "")
loc_df = pytrends.interest_over_time()
loc_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
temp_df = pd.read_csv("../data/blogs_with_analytics.csv", sep="\t", parse_dates=["time"], infer_datetime_format=True, index_col=["index"])
#temp_df = temp_df.drop(columns=temp_df.columns[0:1])
#temp_df.to_csv("../data/blogs_with_analytics.csv", sep="\t")
temp_df
# Out:
#                                                      url  \
# index
# 0      blog/futustories-six-reasons-pasi-left-and-cam...
# 1          blog/foresight-methods-and-strategic-planning
# 2           blog/uncertainty-in-business-volatile-market
# 3           blog/futustories-emma-leena-heikkinens-story
# 4                        blog/safe-route-uncertain-times
# ...                                                  ...
# 780    blog/make-up-simple-solutions-that-fit-your-or...
# 781                        blog/pekka-tarjanne-1937-2010
# 782         blog/user-testing-the-ultimate-reality-check
# 783          blog/quality-time-session-based-testing-faq
# 784    blog/search-the-best-friend-and-worst-enemy-of...
#
#                                                    title       time  \
# index
# 0      FutuStories - Six reasons Pasi left – and came... 2022-09-16
# 1      Foresight methods and strategic planning in bu... 2022-09-13
# 2        Uncertainty in business and how to deal with it 2022-09-12
# 3             FutuStories – Emma-Leena Heikkinen’s story 2022-09-01
# 4      The Safe Route project and how it relates to d... 2022-08-26
# ...                                                  ...        ...
# 780    Make up simple solutions that fit your organiz... 2010-05-10
# 781                           Pekka Tarjanne - 1937-2010 2010-03-19
# 782          User testing - the ultimate "reality check" 2010-03-12
# 783              Quality Time: Session-based testing FAQ 2010-02-26
# 784    Search - The best friend and worst enemy of 21... 2010-02-11
#
#               category                                        description  \
# index
# 0              Culture  For Senior Cloud Consultant Pasi, a change can...
# 1             Strategy  Foresight methods and strategic planning lead ...
# 2              Opinion  Future uncertainty, how to deal with uncertain...
# 3              Culture  To be leader is not naturally given. Emma-Leen...
# 4              Opinion  Good quality data used in the right way is at ...
# ...                ...                                                ...
# 780            Culture  Hello Mikko Viikari! You made a presentation a...
# 781               News  With deep sorrow we announce the loss of our f...
# 782    Ways of Working  Last week, after a couple of months of design ...
# 783           Learning  What is session based testing? Session based t...
# 784      Emerging Tech  Search is by far one of the most powerful navi...
#
#                                                     text  \
# index
# 0      1. I need awesome people around me…\r\nI’d say...
# 1      This is where foresight methods and strategic ...
# 2      The silver lining to all this doom and gloom i...
# 3      What does your role involve?\r\nI’m a client l...
# 4      Safe Route uses data from STRADA - a database ...
# ...                                                  ...
# 780    Hello Mikko Viikari! You made a presentation a...
# 781    With deep sorrow we announce the loss of our f...
# 782    Last week, after a couple of months of design ...
# 783    SESSION BASED TESTING F.A.Q.\r\nWhat is sessio...
# 784    “SEARCH”\r\nThe word seems too sweet and innoc...
#
#                                             introduction             author  \
# index
# 0      For Cloud Archtitect Pasi, a change can be as ...         Pia Hämäri
# 1      If the past few years have taught us anything,...  Annina Antinranta
# 2      Looming global threats like war, recession and...  Andreas Lindqvist
# 3      Human connections, honesty and trust are impor...         Pia Hämäri
# 4      Safe Route was conceived as a new way to think...       Sonja Lakner
# ...                                                  ...                ...
# 780    ['Hello', 'Mikko', 'Viikari!', 'You', 'made', ...         Anni Tölli
# 781    ['With', 'deep', 'sorrow', 'we', 'announce', '...    Tuomas Syrjänen
# 782    ['Last', 'week,', 'after', 'a', 'couple', 'of'...   Matti Parviainen
# 783    ['SESSION', 'BASED', 'TESTING', 'F.A.Q.', 'Wha...      Arttu Tolonen
# 784    Search is by far one of the most powerful navi...      Arttu Tolonen
#
#                              author_job_title  pageviews  ...     exit%  \
# index                                                     ...
# 0                     Marketing Lead, Finland         91  ...  0.527473
# 1      Principal Designer - Emerging Business         33  ...  0.272727
# 2                 Business Director, Futurice         28  ...  0.571429
# 3                     Marketing Lead, Finland        180  ...  0.672222
# 4                   Managing Director, Sweden        105  ...  0.609524
# ...                                       ...        ...  ...       ...
# 780               Account Manager, Consultant          7  ...  0.285714
# 781                    Co-founder, AI Renewal         10  ...  0.500000
# 782         User interface & Concept Designer          6  ...  0.000000
# 783                       Communications Lead          4  ...  0.000000
# 784                       Communications Lead          3  ...  0.666667
#
#        semantic neg score  semantic neu score  semantic pos score  \
# index
# 0                   0.053               0.760               0.187
# 1                   0.020               0.849               0.131
# 2                   0.193               0.704               0.103
# 3                   0.031               0.789               0.180
# 4                   0.065               0.711               0.224
# ...                   ...                 ...                 ...
# 780                 0.004               0.750               0.245
# 781                 0.075               0.669               0.256
# 782                 0.036               0.813               0.151
# 783                 0.000               0.895               0.105
# 784                 0.071               0.753               0.176
#
#        semantic compound score  average_sentence_length  dale_chall  flesch  \
# index
# 0                       0.9990                20.400000        6.88   75.84
# 1                       0.9985                17.888889        7.99   45.05
# 2                      -0.7525                35.500000       11.40   43.90
# 3                       0.9993                19.195652        7.52   68.50
# 4                       0.9995                31.666667        9.07   39.20
# ...                        ...                      ...         ...     ...
# 780                     0.9978                12.076923        8.53   57.57
# 781                     0.9300                14.750000       10.53   56.45
# 782                     0.9793                16.333333        8.39   63.39
# 783                     0.9765                12.090909        8.78   59.09
# 784                     0.9992                22.080000        8.27   65.86
#
#        average_stopword  mmr_lift
# index
# 0              8.707317  2.898231
# 1              7.166667  6.906866
# 2             17.000000  5.223087
# 3              9.847826  3.941215
# 4             14.259259  5.028579
# ...                 ...       ...
# 780            4.384615 -1.000000
# 781            4.250000 -1.000000
# 782            7.416667 -1.000000
# 783            4.181818 -1.000000
# 784            9.800000 -1.000000
#
# [785 rows x 23 columns]

# %%
temp_df["mmr_lift"] = temp_df["mmr_lift"].fillna(-1.0)
temp_df.info()
temp_df.to_csv("../data/blogs_with_analytics_backup.csv", sep="\t")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 785 entries, 0 to 784
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   url                      785 non-null    object
#  1   title                    785 non-null    object
#  2   time                     785 non-null    datetime64[ns]
#  3   category                 785 non-null    object
#  4   description              778 non-null    object
#  5   text                     785 non-null    object
#  6   introduction             785 non-null    object
#  7   author                   785 non-null    object
#  8   author_job_title         785 non-null    object
#  9   pageviews                785 non-null    int64
#  10  unique_pageviews         785 non-null    int64
#  11  avg_time                 785 non-null    float64
#  12  bounce_rate              785 non-null    float64
#  13  exit%                    785 non-null    float64
#  14  semantic neg score       785 non-null    float64
#  15  semantic neu score       785 non-null    float64
#  16  semantic pos score       785 non-null    float64
#  17  semantic compound score  785 non-null    float64
#  18  average_sentence_length  785 non-null    float64
#  19  dale_chall               785 non-null    float64
#  20  flesch                   785 non-null    float64
#  21  average_stopword         785 non-null    float64
#  22  mmr_lift                 785 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(8)
# memory usage: 147.2+ KB
